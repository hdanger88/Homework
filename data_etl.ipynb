# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Resources/medicare-part-d-opioid-prescriber-summary-file-2016.csv"
opioid_data_2016_df = pd.read_csv(csv_file)
opioid_data_2016_df.head()
# Out:
#           NPI NPPES Provider Last Name NPPES Provider First Name  \
# 0  1003000126                ENKESHAFI                   ARDALAN
# 1  1003000142                   KHALIL                    RASHID
# 2  1003000167                  ESCOBAR                     JULIO
# 3  1003000282                BLAKEMORE                     ROSIE
# 4  1003000407                  GIRARDI                     DAVID
#
#    NPPES Provider ZIP Code NPPES Provider State Specialty Description  \
# 0                  21502.0                   MD     Internal Medicine
# 1                  43623.0                   OH        Anesthesiology
# 2                  89403.0                   NV               Dentist
# 3                  37243.0                   TN    Nurse Practitioner
# 4                  15825.0                   PA       Family Practice
#
#    Total Claim Count  Opioid Claim Count  Opioid Prescribing Rate  \
# 0                545                23.0                 4.220183
# ...

# %%
CA_data_df = pd.DataFrame(opioid_data_2016_df.loc[opioid_data_2016_df['NPPES Provider State'] == "CA"])

# %%
CA_data_df.shape
# Out:
# (116512, 11)

# %%
CA_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116512 entries, 10 to 1131540
# Data columns (total 11 columns):
# NPI                                    116512 non-null int64
# NPPES Provider Last Name               116506 non-null object
# NPPES Provider First Name              116510 non-null object
# NPPES Provider ZIP Code                116512 non-null float64
# NPPES Provider State                   116512 non-null object
# Specialty Description                  116512 non-null object
# Total Claim Count                      116512 non-null int64
# Opioid Claim Count                     83489 non-null float64
# Opioid Prescribing Rate                83489 non-null float64
# Long-Acting Opioid Claims              101023 non-null float64
# Long-Acting Opioid Prescribing Rate    37304 non-null float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 10.7+ MB

# %%
CA_data_df
# Out:
#                 NPI NPPES Provider Last Name NPPES Provider First Name  \
# 10       1003000639                BENHARASH                    PEYMAN
# 14       1003000837                     JOHN                   RICHARD
# 17       1003001017                  NICHOLS                  LAWRENCE
# 18       1003001132              VIGGIANELLI                   MICHAEL
# 21       1003001363                  STEVENS                   CHARLES
# 25       1003001645                  TRIVEDI                     VINOD
# 31       1003002049               SRINIVASAN                   LAKSHMI
# 41       1003002718                       LA                     TRANG
# 42       1003002742                  LOCKMAN                     BRETT
# 48       1003002932                  GALUSKA                   MICHAEL
# 55       1003003641                 PARTNOFF                      RYAN
# 56       1003003781                    CHOTI                     SUPAK
# ...

# %%
CA_data_df = CA_data_df.reset_index(drop=True)
CA_data_df
# Out:
#                NPI NPPES Provider Last Name NPPES Provider First Name  \
# 0       1003000639                BENHARASH                    PEYMAN
# 1       1003000837                     JOHN                   RICHARD
# 2       1003001017                  NICHOLS                  LAWRENCE
# 3       1003001132              VIGGIANELLI                   MICHAEL
# 4       1003001363                  STEVENS                   CHARLES
# 5       1003001645                  TRIVEDI                     VINOD
# 6       1003002049               SRINIVASAN                   LAKSHMI
# 7       1003002718                       LA                     TRANG
# 8       1003002742                  LOCKMAN                     BRETT
# 9       1003002932                  GALUSKA                   MICHAEL
# 10      1003003641                 PARTNOFF                      RYAN
# 11      1003003781                    CHOTI                     SUPAK
# ...

# %%
CA_data_df.loc[CA_data_df['Specialty Description'] == "Dermatology"]
# Out:
#                NPI NPPES Provider Last Name NPPES Provider First Name  \
# 2       1003001017                  NICHOLS                  LAWRENCE
# 92      1003043340                   LIPTON                     SHIRA
# 127     1003060492                  STEVENS                      SETH
# 211     1003106014                     KANE                     SINAE
# 225     1003117649                  KREIDEL                     MARIT
# 254     1003133216                    LEONG                     TRACY
# 509     1003827346                  ROTHMAN                      RUTH
# 580     1003840869                    MINES                      JILL
# 632     1003859802                 YAMAMOTO                   RICHARD
# 651     1003865841                      LEE                      CHAI
# 697     1003884925                   COLMAN                   GREGORY
# 810     1003922162                  SHAMBAN                       AVA
# ...

# %%
CA_data_df.count()
# Out:
# NPI                                    116512
# NPPES Provider Last Name               116506
# NPPES Provider First Name              116510
# NPPES Provider ZIP Code                116512
# NPPES Provider State                   116512
# Specialty Description                  116512
# Total Claim Count                      116512
# Opioid Claim Count                      83489
# Opioid Prescribing Rate                 83489
# Long-Acting Opioid Claims              101023
# Long-Acting Opioid Prescribing Rate     37304
# dtype: int64

# %%
CA_data_df = CA_data_df.fillna(0)

# %%
CA_data_df.count()
# Out:
# NPI                                    116512
# NPPES Provider Last Name               116512
# NPPES Provider First Name              116512
# NPPES Provider ZIP Code                116512
# NPPES Provider State                   116512
# Specialty Description                  116512
# Total Claim Count                      116512
# Opioid Claim Count                     116512
# Opioid Prescribing Rate                116512
# Long-Acting Opioid Claims              116512
# Long-Acting Opioid Prescribing Rate    116512
# dtype: int64

# %%
CA_data_df["NPPES Provider ZIP Code"] = pd.to_numeric(CA_data_df["NPPES Provider ZIP Code"], downcast = "signed")

# %%
CA_data_df
# Out:
#                NPI NPPES Provider Last Name NPPES Provider First Name  \
# 0       1003000639                BENHARASH                    PEYMAN
# 1       1003000837                     JOHN                   RICHARD
# 2       1003001017                  NICHOLS                  LAWRENCE
# 3       1003001132              VIGGIANELLI                   MICHAEL
# 4       1003001363                  STEVENS                   CHARLES
# 5       1003001645                  TRIVEDI                     VINOD
# 6       1003002049               SRINIVASAN                   LAKSHMI
# 7       1003002718                       LA                     TRANG
# 8       1003002742                  LOCKMAN                     BRETT
# 9       1003002932                  GALUSKA                   MICHAEL
# 10      1003003641                 PARTNOFF                      RYAN
# 11      1003003781                    CHOTI                     SUPAK
# ...

# %%
CA_data_df.to_csv("CA_overdose_data.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-18-644155a39cef> in <module>
# ----> 1 CA_data_df.to_csv("CA_overdose_data.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
#     155                                      encoding=encoding,
# ...

# %% [markdown]
# connection_string = "root:v=#nJrC52Z@3306:  "
# engine = create_engine(f'mysql://{connection_string}')

# %% [markdown]
# engine.table_names()
